# %%
#1. Write a Python program to check if a number is positive, negative or zero.
num= float(input("enter the num: "))
 
if num>0:
  print('the num is positive')

elif num==0:
  print('the num is zero')

else:
  print('the num is negative')
# Out:
# enter the num: 4
# the num is positive

# %%
#2. Write a Python program to get the Factorial number of given number.
num =int(input("enter the number "))

factorial=1

if(num < 0):
  print('fact doest exists')
elif(num == 0):
  print('fact of 0 is 1')
else:
  for i in range(1,num+1):
   factorial = factorial*i
  print("The factorial of",num,"is",factorial)
# Out:
# enter the number 5
# The factorial of 5 is 120

# %%
#3. Write a Python program to get the Fibonacci series of given range.

# %%
#4. How memory is managed in Python?
'''in python memory allocation and de-allocation method is automatic as python developer creates a "Garbage collector"
-> GARBAGE COLLECTOR- it is the process in which interpreter frees up the memory use when not in use to make it available for other object
-> REFERENCE COUNTING- it works by counting no. of items an object is referenced by other object. When that reference to an object is removed and it become zero.it is 
deallocated and its sapce is given to another object
-> There are two type of memory 1. stack memory- it stores item for short period of time , 
2. Heap memory- it creates a dynamic allocation for item in memory'''

# %%
#5. What is the purpose continue statement in python?
'''Continue is used to end the current iteration in for or while loop and continue to the next iteration '''

# %%
#6. Write python program that swap two number with temp variable and without temp variable.
x= int(input("enter x="))
y= int(input('enter y='))

temp = x
x = y
y= temp

print('value of x',x)
print('value of y',y)
# Out:
# enter x=2
# enter y=5
# value of x 5
# value of y 2

# %%
# Without using temp varaible
x = int(input("x: "))
y = int(input("y: "))

x,y = y,x
print("swap x: ",x)
print("swap y: ",y)
# Out:
# x: 3
# y: 4
# swap x:  4
# swap y:  3

# %%
#7. Write a Python program to find whether a given number is even or odd, print out an appropriate message to the user.
n = int(input("enter num: "))
if  n>0:
  if n%2==0:
    print("it is even")
  else: 
    print("it is odd")
else:
  print("invalid")
# Out:
# enter num: 23
# it is odd

# %%
#8. Write a Python program to test whether a passed letter is a vowel or not
vowel = ['A','E','I','O','U','a','e','i','o','u']
char = input("enter alphabet: ")
if char in vowel:
  print("vowles")
else:
  print("consonant")
# Out:
# enter alphabet: s
# consonant

# %%
#9. Write a Python program to sum of three given integers.However, if two values are equal sum will be zero
a= int(input("a: "))
b= int(input("b: "))
c= int(input("c: "))
total = a+b+c
if a==b or a==c or b==c:
  print("sum is zero")
else:
  print("total is:",total)
# Out:
# a: 2
# b: 2
# c: 3
# sum is zero

# %%
#10.Write a Python program that will return true ifthe two given integervalues or their sums or difference is 5.
a = int(input("a: "))
b = int(input("b: "))
if a==b or (a+b==5) or (a-b==5):
  print("true")
else:
  print("false")
# Out:
# a: 2
# b: 4
# false

# %%
#11. Write a python program to sum of the first n positive integers.
n = int(input("n: "))
x = n+1
sum = (n*x)/2
print("sum is:",+sum)
# Out:
# n: 5
# sum is: 15.0

# %%
#12. Write a Python program to calculate the length of a string
s = input("enter string:")
s = len(s)
print(s)
# Out:
# enter string:arputa3010
# 10

# %%
#13. Write a Python program to count the number of characters (character frequency) in a string
string = input("enter a string: ")
for i in string:
  char_count = string.count(i)
  print(i, ':' ,char_count, end=" ")
# Out:
# enter a string: hello world
# h : 1 e : 1 l : 3 l : 3 o : 2   : 1 w : 1 o : 2 r : 1 l : 3 d : 1

# %%
#14. What are negative indexes and why are they used?

# %%
#15. Write a Python program to count occurrences of a substring in a string.
str="It is raining today"
substr = input("enter a substr: ")
a= str.count(substr)
print(a)
# Out:
# enter a substr: is
# 1

# %%
#16. Write a Python program to count the occurrences of each word in a given sentence
string = "hello world"
string.count(string)
# Out:
# 1

# %%
#17. Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.
x= (input("enter str1:"))
y = (input("enter str2:"))

a = x.replace(x[0:2],y[0:2])
b = y.replace(y[0:2],x[0:2])

print(a+' '+b)
# Out:
# enter str1:arpita
# enter str2:patel
# papita artel

# %%
#18. Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing' then add 'ly'
#  instead if the string length of the given string is less than 3, leave it unchanged'''

# %%
#19. Write a Python program to find the first appearance of the substring 'not'and 'poor' froma given string, if 'not' follows the 'poor', replace the whole
#  'not'...'poor'substring with 'good'. Return the resulting string.

# %%
#20. Write a Python function that takes a list of words and returns the length of the longest one

# %%
#21.Write a Python function to reverses a string if its length is a multiple of 4

# %%
22. Write a Python program to get a string made of the first 2 and the last 2 chars from a given a string. Ifthe string length islessthan 2,return instead
of the empty string.
o Sample String:w3resource'
o Expected Result: 'w3ce'
o Sample String: 'w3'
o Expected Result: 'w3w3'
o Sample String: ' w'
o Expected Result: Empty String

# %%
#23. Write a Python function to insert a string in the middle of a string

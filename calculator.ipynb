# %%
#calculator using functionng
def add(x,y):
    return x+y
def sub(x,y):
    return x-y
def mul(x,y):
    return x*y
def div(x,y):
    return x/y

x = int(input("enter x : "))
y = int(input("enter y : "))


is_quit = False
while is_quit == False:
    print("SELECT FROM BELOW")
    print("1.add\n2.sub\n3.mul\n4.div\n5.exit")
    query = int(input("enter your choice: "))

    if query == 1:
      add(x,y)
      print("ADDITION OF",x,"and",y,"is",add(x,y))
      print("")
    elif query == 2:
      sub(x,y)
      print("SUBSTRACTION OF",x,"and",y,"is",sub(x,y))
      print("")
    elif query == 3:
      mul(x,y)
      print("MULTIPLICATION OF",x,"and",y,"is",mul(x,y))
      print("")
    elif query == 4:
      div(x,y)
      print("DIVISON OF",x,"and",y,"is",div(x,y))
      print("")
    elif query == 5:
      is_quit = True
    else:
      print("enter a valid choice")
else:
  False
# Out:
# enter x : 10
# enter y : 5
# SELECT FROM BELOW
# 1.add
# 2.sub
# 3.mul
# 4.div
# 5.exit
# enter your choice: 1
# ADDITION OF 10 and 5 is 15
#
# SELECT FROM BELOW
# 1.add
# 2.sub
# 3.mul
# 4.div
# 5.exit
# enter your choice: 2
# SUBSTRACTION OF 10 and 5 is 5
#
# SELECT FROM BELOW
# 1.add
# 2.sub
# 3.mul
# 4.div
# 5.exit
# enter your choice: 3
# MULTIPLICATION OF 10 and 5 is 50
#
# SELECT FROM BELOW
# 1.add
# 2.sub
# 3.mul
# 4.div
# 5.exit
# enter your choice: 4
# DIVISON OF 10 and 5 is 2.0
#
# SELECT FROM BELOW
# 1.add
# 2.sub
# 3.mul
# 4.div
# 5.exit
# enter your choice: 5

# %%
# clac using class
class calculator:
  def __init__(self,x,y):
    self.x = x
    self.y = y

  def add(self):
    return self.x + self.y

  def sub(self):
    return self.x - self.y

  def mul(self):
    return self.x * self.y

  def div(self):
    return self.x / self.y

x = int(input("enter x : "))
y = int(input("enter y : "))

c = calculator(x,y)

is_quit =  False
while is_quit == False:
  print("SELECT FROM BELOW")
  print("1.add\n2.sub\n3.mul\n4.div\n5.exit")
  query = int(input("enter your choice: "))

  if query == 1:
    print("addition is: ",c.add())
    print('')
  elif query == 2:
    print("Substraction is: ",c.sub())
    print('')
  elif query == 3:
    print("multiplication is: ",c.mul())
    print('')
  elif query == 4:
    print("division is: ",c.div())
    print('')
  elif query == 5:
    is_quit = True
  else:
    print("choose number between 1 -5 ")
# Out:
# enter x : 10
# enter y : 5
# SELECT FROM BELOW
# 1.add
# 2.sub
# 3.mul
# 4.div
# 5.exit
# enter your choice: 1
# addition is:  15
#
# SELECT FROM BELOW
# 1.add
# 2.sub
# 3.mul
# 4.div
# 5.exit
# enter your choice: 2
# Substraction is:  5
#
# SELECT FROM BELOW
# 1.add
# 2.sub
# 3.mul
# 4.div
# 5.exit
# enter your choice: 3
# multiplication is:  50
#
# SELECT FROM BELOW
# 1.add
# 2.sub
# 3.mul
# 4.div
# 5.exit
# enter your choice: 4
# division is:  2.0
#
# SELECT FROM BELOW
# 1.add
# 2.sub
# 3.mul
# 4.div
# 5.exit
# enter your choice: 5

# %%
# calculator with n number of inputs
def add(*add):
  s = 0
  for i in add:
    s += i
    return s
def sub(*minus):
    return sub
def mul(x,y):
    return x*y
def div(x,y):
    return x/y

# %%
def add(*add):
  s = 0
  for i in add:
    s += i
  return s

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ded5ba42480f> in <module>()
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
def sub(x,*minus):
  s = x
  for i in minus:
    x -= i 
  return x

# %%
x = int(input("enter x:"))
minus = int(input(print("enter other nums: ")))
print(f'{x}-{minus}')

# %%
sub(10,5,2,1)
# Out:
# 2

# %%
def mul(x,*multiply):
  s = x
  for i in multiply:
     x = x * i
  return x

# %%
mul(1,2,3,4,10)
# Out:
# 240

# %%
def div(x,*division):
  s = x
  for i in division:
    x = x/i
  return x

# %%
div(10,2,2)
# Out:
# 2.5

# %%
#calculator using n numbers of input
def add(*add):
  s = 0
  for i in add:
    s += i
  return s

def sub(x,*minus):
  s = x
  for i in minus:
    x -= i 
  return x

def mul(x,*multiply):
  s = x
  for i in multiply:
     x = x * i
  return x

def div(x,*division):
  s = x
  for i in division:
    x = x/i
  return x

# %%
# Adding n numbers from user input
n = input("enter n :")
n = n.split(",")
print(n)
# Out:
# enter n :4,5
# ['4', '5']

# %%
sum =0
for i in n:
  if i.isnumeric() == True:
    a = int(i)
    sum = sum + a
print(sum)
# Out:
# 55

# %%
#subtracting n numbers from user input
x = int(input("enter x: "))
n = input("enter n :")
n = n.split(",")
sum = x
for i in n:
  if i.isnumeric() == True:
    a = int(i)
    x = x - a
print(x)
# Out:
# enter x: 12
# enter n :1,2,3,4
# 2

# %%
def add(*add):
  x = input("enter numbs: ")
  s = 0
  for i in x:
    add = int(x)
    for i in add:
      s += i
  return s

# %%
add()
# Out:
# enter numbs: 1,2,3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-d5d29de3ed94> in <module>()
# ----> 1 add()
#
# <ipython-input-89-287022ec9eda> in add(*add)
#       3   s = 0
#       4   for i in x:
# ----> 5     add = int(x)
#       6     for i in add:
#       7       s += i
#
# ValueError: invalid literal for int() with base 10: '1,2,3'
